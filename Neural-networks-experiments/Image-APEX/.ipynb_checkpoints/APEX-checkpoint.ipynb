# %% [markdown]
# # Neuronky projekt 2

# %%
using PyPlot
using Images
using PyCall
@pyimport numpy as np 
@pyimport numpy.linalg as LA

# %% [markdown]
# ## Functions

# %%
# normalization
function normalize(data)
    x = mean(data)
    data -= x
    σ = maximum(data) - minimum(data)
    data /= σ
    return data, x, σ
end

# de-normalization
function denormalize(data, x, σ)
    data *= σ
    data += x
    return data
end

# Partition of data -> (i,j)th place
function partition(data, s, i, j)
    part = data[ s*(i-1) + 1 : s*i , s*(j-1) + 1 : s*j ]
    return part
end

# Insert partition into new dataset
function insert(data_new, part_new, i, j)
    data_new[ s*(i-1) + 1 : s*i , s*(j-1) + 1 : s*j ] = part_new
    return data_new
end  

# Stitching all partitions into new dataset
function stitch(img, P)
    (data, x, σ) = normalize(img)
    data = Array{Float64}(data)
    
    data_new = np.zeros((Height,Width))
    println("Stitching")

    for i=1:N_h
        for j = 1:N_w
            part = partition(data, s, i, j)
            X = reshape(part, (s^2,1))
            if (length(P) == 64)
                X_new = P * dot(P,X)
            else
                X_new = P' * P * X
            end
            part_new = reshape(X_new, (s,s))
            data_new = insert(data_new, part_new, i, j)
        end
    end
    img_new = denormalize(data_new, x, σ)
    if (minimum(img_new) < 0) img_new -= minimum(img_new) end
    if (maximum(img_new) > 1) img_new /= maximum(img_new) end
    
    return img_new
end

# eigenvalues calculation
function eigen(img,P)
    (data, x, σ) = normalize(img)
    Mcorr = zeros(s^2,s^2)
    for i=1:N_h
        for j = 1:N_w
            part = partition(data, s, i, j)
            X = reshape(part, (s^2,1))
            X = P' * P * X
            Mcorr += X*X' / (Height*Width)
        end
    end
    w,v = LA.eig(Mcorr)
    return w,v
end
# Out:
# WARNING: Method definition normalize(Any) in module Main at In[75]:3 overwritten at In[177]:3.
# WARNING: Method definition denormalize(Any, Any, Any
# eigen (generic function with 1 method)
# ) in module Main at In[75]:12 overwritten at In[177]:12.
# WARNING: Method definition partition(Any, Any, Any, Any) in module Main at In[75]:19 overwritten at In[177]:19.
# WARNING: Method definition insert(Any, Any, Any, Any) in module Main at In[75]:25 overwritten at In[177]:25.
# WARNING: Method definition stitch(Any, Any) in module Main at In[75]:31 overwritten at In[177]:31.
# WARNING: Method definition eigen(Any, Any) in module Main at In[75]:59 overwritten at In[177]:59.

# %% [markdown]
# ## Data import and preprocessing

# %%
img = imread("elaine.png")

Height, Width = size(img)
s = 8
N_h = Int(Height/s)
N_w = Int(Width/s)

colorview(Gray, img)
# Out:
# 256×256 Array{Gray{Float32},2}:
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)  …  Gray{Float32}(0.345098)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.368627)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.380392)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.388235)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.415686)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)  …  Gray{Float32}(0.423529)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.431373)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.45098)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.454902)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.482353)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)  …  Gray{Float32}(0.509804)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.498039)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.745098)     Gray{Float32}(0.509804)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float32}(0.337255)  Gray{Float32}(0.32549)      Gray{Float32}(0.690196)
#  Gray{Float32}(0.301961)  Gray{Float32}(0.313726)  …  Gray{Float32}(0.698039)
#  Gray{Float32}(0.27451)   Gray{Float32}(0.32549)      Gray{Float32}(0.682353)
#  Gray{Float32}(0.27451)   Gray{Float32}(0.305882)     Gray{Float32}(0.694118)
#  Gray{Float32}(0.282353)  Gray{Float32}(0.27451)      Gray{Float32}(0.694118)
#  Gray{Float32}(0.305882)  Gray{Float32}(0.27451)      Gray{Float32}(0.682353)
#  Gray{Float32}(0.301961)  Gray{Float32}(0.243137)  …  Gray{Float32}(0.682353)
#  Gray{Float32}(0.262745)  Gray{Float32}(0.258824)     Gray{Float32}(0.67451)
#  Gray{Float32}(0.258824)  Gray{Float32}(0.25098)      Gray{Float32}(0.67451)
#  Gray{Float32}(0.25098)   Gray{Float32}(0.262745)     Gray{Float32}(0.67451)
#  Gray{Float32}(0.243137)  Gray{Float32}(0.247059)     Gray{Float32}(0.682353)
#  Gray{Float32}(0.211765)  Gray{Float32}(0.258824)  …  Gray{Float32}(0.654902)

# %% [markdown]
# ## APEX algorithm

# %%
function APEX(img, s, P, W, α, epochs, m)
    
    (data, x, σ) = normalize(img)
    data = Array{Float64}(data)
    
    Y = zeros(m)
    β = γ = α
    
    for n=randperm(N_h*N_w)
        i = div(n-1,N_w) + 1
        j = (n-1)%N_w + 1
    
        part = partition(data, s, i, j)
        
        X = reshape(part, (s^2,1))
        
        if (m==1)  # Oja's part
            Y[1] = dot(P[1,:], X)
            P[1,:] += β * (Y[1]*X - (Y[1])^2 * P[1,:])
        else 
            Y[1:m] = P[1:m,:] * X
            Y[m] += dot(W[1:m-1], Y[1:m-1])
            
            P[m,:] += β * (Y[m]*X - (Y[m])^2 * P[m,:])
            W[1:m-1] -= γ * (Y[m]*Y[1:m-1] + (Y[m])^2 * W[1:m-1])
        end
    end
    
    return P, W
end
# Out:
# APEX (generic function with 1 method)

# %% [markdown]
# ## Training

# %%
# Three PCs are already found by previous calculation

α = 1e-3  # step = aprrox 1/(N_h * N_w)
ϵ = 1e-3  # initialization parameter
epochs = 5000
M=20  # number of PCs

P = ϵ * ( 2*rand(M, s^2) - 1)  
println("Compressing...")

for m = 1:5
    W = ϵ * ( 2*rand(m-1))
    println("Finding PC $m :")
    
    for ep=1:epochs    
        if (ep%500 == 0) println("Starting epoch $ep, W=$(mean(W))") end  #mean(W) is my testing parameter
        P, W = APEX(img, s, P, W, α, epochs, m)
        
    end
end
# Out:
# Compressing...
# Finding PC 4 :
# Starting epoch 500, W=-0.13525010673951718
# Starting epoch 1000, W=-0.13210856986987787
# Starting epoch 1500, W=-0.13204913104423163
# Starting epoch 2000, W=-0.13236007405187547
# Starting epoch 2500, W=-0.13213202398427154
# Starting epoch 3000, W=-0.13208587983797102
# Starting epoch 3500, W=-0.13170758318054096
# Starting epoch 4000, W=-0.13177169633749833
# Starting epoch 4500, W=-0.1322129729592715
# Starting epoch 5000, W=-0.13204476182595004
# Finding PC 5 :
# Starting epoch 500, W=-0.6730809155830211
# Starting epoch 1000, W=-0.6719273505529401
# Starting epoch 1500, W=-0.6730921259651286
# Starting epoch 2000, W=-0.6722568482523714
# Starting epoch 2500, W=-0.6726452533472812
# Starting epoch 3000, W=-0.6725223586929531
# Starting epoch 3500, W=-0.6730633258057361
# Starting epoch 4000, W=-0.6734286822442951
# Starting epoch 4500, W=-0.6721830407023768
# Starting epoch 5000, W=-0.6723270904908664
# Finding PC 6 :
# Starting epoch 500, W=0.0019134467825126134
# Starting epoch 1000, W=0.002166537520157265
# Starting epoch 1500, W=0.0004194169214738898
# Starting epoch 2000, W=0.0012648551708515762
# Starting epoch 2500, W=0.0011813278456641093
# Starting epoch 3000, W=-0.000595610789626393
# Starting epoch 3500, W=0.001967259827894123
# Starting epoch 4000, W=0.0037061892409318863
# Starting epoch 4500, W=0.0023877251439977545
# Starting epoch 5000, W=0.0012232840754713998
# Finding PC 7 :
# Starting epoch 500, W=-0.001044071051840797
# Starting epoch 1000, W=0.0001624004157836983
# Starting epoch 1500, W=-0.0005734771376429685
# Starting epoch 2000, W=-1.5669122291555658e-5
# Starting epoch 2500, W=-0.0004389878400517289
# Starting epoch 3000, W=0.000481329787523403
# Starting epoch 3500, W=-0.0001781438403933687
# Starting epoch 4000, W=0.0009308602988202428
# Starting epoch 4500, W=0.0006231318364427571
# Starting epoch 5000, W=0.0011275521168679023
# Finding PC 8 :
# Starting epoch 500, W=-0.01687966901399018
# Starting epoch 1000, W=0.0011731421612092556
# Starting epoch 1500, W=0.0009619500229470841
# Starting epoch 2000, W=0.0006818115546179217
# Starting epoch 2500, W=0.0010662054156992766
# Starting epoch 3000, W=-0.0002823787695158325
# Starting epoch 3500, W=0.0004745858120360902
# Starting epoch 4000, W=0.0009349022181827723
# Starting epoch 4500, W=8.949937720956215e-5
# Starting epoch 5000, W=0.00037918764820307673
# Finding PC 9 :
# Starting epoch 500, W=-0.00973855771901666
# Starting epoch 1000, W=-0.0010713010012972088
# Starting epoch 1500, W=-0.0011295105599798628
# Starting epoch 2000, W=-0.0003624469315560954
# Starting epoch 2500, W=-0.0007830890105632339
# Starting epoch 3000, W=-0.0008376996369245519
# Starting epoch 3500, W=-0.0002758356590132842
# Starting epoch 4000, W=-0.0015594243860904528
# Starting epoch 4500, W=-0.0002393820748065795
# Starting epoch 5000, W=-0.0004453372321618678
# Finding PC 10 :
# Starting epoch 500, W=-0.013648065198484292
# Starting epoch 1000, W=-0.012467800876244002
# Starting epoch 1500, W=-0.00010566705833361171
# Starting epoch 2000, W=0.00040135175815784655
# Starting epoch 2500, W=6.23447496750163e-5
# Starting epoch 3000, W=0.0006348333240925529
# Starting epoch 3500, W=-0.00010776838741269194
# Starting epoch 4000, W=-0.00015553259622662146
# Starting epoch 4500, W=0.0003913736918601772
# Starting epoch 5000, W=-6.132612070328488e-5
# Finding PC 11 :
# Starting epoch 500, W=-0.018155765567751347
# Starting epoch 1000, W=-0.02699434798378414
# Starting epoch 1500, W=-0.006565945861590131
# Starting epoch 2000, W=0.0004286585601801323
# Starting epoch 2500, W=0.0009643820716708275
# Starting epoch 3000, W=0.0008787361856150998
# Starting epoch 3500, W=0.0006346925427707431
# Starting epoch 4000, W=0.0009630316848652226
# Starting epoch 4500, W=0.0004085639427539842
# Starting epoch 5000, W=0.0006103482975523
# Finding PC 12 :
# Starting epoch 500, W=-0.020143420781801626
# Starting epoch 1000, W=-0.032575027728057496
# Starting epoch 1500, W=-0.006978253940755782
# Starting epoch 2000, W=-0.0012925314506736106
# Starting epoch 2500, W=-0.0010607428225383154
# Starting epoch 3000, W=-0.0008996178123538818
# Starting epoch 3500, W=-0.0009331868313641806
# Starting epoch 4000, W=-0.0014623736239837612
# Starting epoch 4500, W=-0.0013216799164742497
# Starting epoch 5000, W=-0.0013662234182254145
# Finding PC 13 :
# Starting epoch 500, W=-0.011393221947397149
# Starting epoch 1000, W=-0.019629706507768668
# Starting epoch 1500, W=-0.024648054367435137
# Starting epoch 2000, W=-0.009153038853637241
# Starting epoch 2500, W=-0.0018387561577922213
# Starting epoch 3000, W=-0.0006548567302410783
# Starting epoch 3500, W=-0.0006146094661341883
# Starting epoch 4000, W=-0.0005734317089775753
# Starting epoch 4500, W=-0.0008249927249484824
# Starting epoch 5000, W=-0.000935592026563699
# Finding PC 14 :
# Starting epoch 500, W=-0.005659685960923029
# Starting epoch 1000, W=-0.013387727515827107
# Starting epoch 1500, W=-0.020720030903710888
# Starting epoch 2000, W=-0.015979227450270583
# Starting epoch 2500, W=-0.003920866501376383
# Starting epoch 3000, W=-0.0012737732790407215
# Starting epoch 3500, W=-0.000540864319150578
# Starting epoch 4000, W=-0.0004772548883910844
# Starting epoch 4500, W=-0.0005475917176885986
# Starting epoch 5000, W=-0.0006270545818131642
# Finding PC 15 :
# Starting epoch 500, W=-0.006373326002587276
# Starting epoch 1000, W=-0.010460986671406618
# Starting epoch 1500, W=-0.014244362669429782
# Starting epoch 2000, W=-0.014444799884080454
# Starting epoch 2500, W=-0.004498756990255113
# Starting epoch 3000, W=0.00016024781245929605
# Starting epoch 3500, W=0.0010968793076875855
# Starting epoch 4000, W=0.001344047644915363
# Starting epoch 4500, W=0.0017262550133317013
# Starting epoch 5000, W=0.001316265818625603
# Finding PC 16 :
# Starting epoch 500, W=-0.011830665160140814
# Starting epoch 1000, W=-0.022015461827053887
# Starting epoch 1500, W=-0.031185288612959057
# Starting epoch 2000, W=-0.03984598472551546
# Starting epoch 2500, W=-0.04671962204551572
# Starting epoch 3000, W=-0.037753684917445726
# Starting epoch 3500, W=-0.01453651183159812
# Starting epoch 4000, W=-0.004953891163452156
# Starting epoch 4500, W=-0.00243441514235979
# Starting epoch 5000, W=-0.001737890656859281
# Finding PC 17 :
# Starting epoch 500, W=-0.006484582673354682
# Starting epoch 1000, W=-0.011349080559707148
# Starting epoch 1500, W=-0.01576377047633002
# Starting epoch 2000, W=-0.01991569328102637
# Starting epoch 2500, W=-0.022810001358314215
# Starting epoch 3000, W=-0.018489185393379015
# Starting epoch 3500, W=-0.007598113229522416
# Starting epoch 4000, W=-0.0017466210245134061
# Starting epoch 4500, W=0.00028747089523471466
# Starting epoch 5000, W=0.0007433374585428657
# Finding PC 18 :
# Starting epoch 500, W=-9.455631537166538e-5
# Starting epoch 1000, W=-0.0002971341733202248
# Starting epoch 1500, W=-0.00019714668933019155
# Starting epoch 2000, W=0.0003529607944099447
# Starting epoch 2500, W=0.0016143844037019303
# Starting epoch 3000, W=0.003626014578100898
# Starting epoch 3500, W=0.00445719003087993
# Starting epoch 4000, W=0.003556356960547377
# Starting epoch 4500, W=0.002489379055711468
# Starting epoch 5000, W=0.0019896149106540632
# Finding PC 19 :
# Starting epoch 500, W=-0.009770577381285166
# Starting epoch 1000, W=-0.016892612139841952
# Starting epoch 1500, W=-0.024446167491571854
# Starting epoch 2000, W=-0.03367742685671515
# Starting epoch 2500, W=-0.04558724498102434
# Starting epoch 3000, W=-0.061104439836441635
# Starting epoch 3500, W=-0.07829534891138837
# Starting epoch 4000, W=-0.0825699553577411
# Starting epoch 4500, W=-0.062076029310337004
# Starting epoch 5000, W=-0.039573548104866504
# Finding PC 20 :
# Starting epoch 500, W=-0.0037798837164075574
# Starting epoch 1000, W=-0.006031040962267354
# Starting epoch 1500, W=-0.007860169527384143
# Starting epoch 2000, W=-0.009743278956083366
# Starting epoch 2500, W=-0.012027438422225416
# Starting epoch 3000, W=-0.015429862805514581
# Starting epoch 3500, W=-0.02136586234502135
# Starting epoch 4000, W=-0.030067368369602023
# Starting epoch 4500, W=-0.035684661447839536
# Starting epoch 5000, W=-0.036010438871099296

# %% [markdown]
# ## Testing properties of PCs

# %%
println("Eigenvectors scalar products (should = 1):")
prod = zeros(M)
for i=1:M
    prod[i] = round( dot(P[i,:],P[i,:]), 5)
    println("$(prod[i])")
end
println("...")

println("Eigenvectors visualization:")
eigenfull = np.zeros((s,10*s))
(data, x, σ) = normalize(img)
for n=1:10
    eigenvec = reshape(P[n,:], (s,s)) 
    if (minimum(eigenvec) < 0) eigenvec -= minimum(eigenvec) end
    if (maximum(eigenvec) > 1) eigenvec /= maximum(eigenvec) end
    eigenfull[:, s*(n-1)+1:s*n] = eigenvec
end
#save("eigens.png", eigenfull)
colorview(Gray, eigenfull)
# Out:
# Eigenvectors scalar products (should = 1):
# 1.00018
# 1.00075
# 1.00476
# 1.12054
# 6.66744
# 0.99481
# 0.99392
# 0.99425
# 0.99321
# 0.99388
# 0.99376
# 0.99364
# 0.99469
# 0.99436
# 0.99381
# 0.99409
# 0.99497
# 0.99844
# 1.83146
# 1.64892
# ...
# Eigenvectors visualization:
# 8×80 Array{Gray{Float64},2}:
#  Gray{Float64}(0.111954)  Gray{Float64}(0.116484)  …  Gray{Float64}(0.482356)
#  Gray{Float64}(0.114138)  Gray{Float64}(0.120816)     Gray{Float64}(0.450731)
#  Gray{Float64}(0.116907)  Gray{Float64}(0.123684)     Gray{Float64}(0.404594)
#  Gray{Float64}(0.118295)  Gray{Float64}(0.125834)     Gray{Float64}(0.3169)
#  Gray{Float64}(0.118279)  Gray{Float64}(0.125613)     Gray{Float64}(0.294043)
#  Gray{Float64}(0.117497)  Gray{Float64}(0.123879)  …  Gray{Float64}(0.391146)
#  Gray{Float64}(0.114885)  Gray{Float64}(0.119692)     Gray{Float64}(0.549573)
#  Gray{Float64}(0.11129)   Gray{Float64}(0.115097)     Gray{Float64}(0.655683)

# %% [markdown]
# ## Covariance matrix and eigenvalues

# %%
w,v = eigen(img, eye(s^2))
wnew,vnew = eigen(img, Pnew)
println(real(w[1:10]))
println(real(wnew[1:10]))
# Out:
# [0.0348016,0.00286692,0.00221442,0.0008043,0.000575745,0.000300495,0.000217004,0.000176011,0.000115864,0.000101551]
# [0.0353889,0.00286985,0.00218128,0.000569704,0.000296839,0.000214499,0.000173612,6.64324e-5,9.23688e-5,0.000100428]

# %% [markdown]
# ## Reconstruction

# %%
# Manual selecting good PCs according to test above
good = [1,2,3,6,7,8,9,10,11,12,13]
Pnew = P[good,:]
pic = stitch(img, Pnew)
error = 10^4 * sum((img - pic).^2) / (Width*Height)
println("Error measured: $error")
#save("NNelaine.png", pic)
colorview(Gray, pic)
# Out:
# Stitching
# Error measured: 55.25057727358878
# 256×256 Array{Gray{Float64},2}:
#  Gray{Float64}(0.65513)   Gray{Float64}(0.655094)  …  Gray{Float64}(0.351049)
#  Gray{Float64}(0.657985)  Gray{Float64}(0.659821)     Gray{Float64}(0.347569)
#  Gray{Float64}(0.66374)   Gray{Float64}(0.663303)     Gray{Float64}(0.350355)
#  Gray{Float64}(0.668698)  Gray{Float64}(0.668791)     Gray{Float64}(0.354974)
#  Gray{Float64}(0.673667)  Gray{Float64}(0.675107)     Gray{Float64}(0.359738)
#  Gray{Float64}(0.678708)  Gray{Float64}(0.682272)  …  Gray{Float64}(0.360832)
#  Gray{Float64}(0.682934)  Gray{Float64}(0.687313)     Gray{Float64}(0.352412)
#  Gray{Float64}(0.683996)  Gray{Float64}(0.686967)     Gray{Float64}(0.349373)
#  Gray{Float64}(0.65501)   Gray{Float64}(0.655221)     Gray{Float64}(0.435968)
#  Gray{Float64}(0.658068)  Gray{Float64}(0.660062)     Gray{Float64}(0.437148)
#  Gray{Float64}(0.664058)  Gray{Float64}(0.663587)  …  Gray{Float64}(0.444991)
#  Gray{Float64}(0.669036)  Gray{Float64}(0.668831)     Gray{Float64}(0.45082)
#  Gray{Float64}(0.673814)  Gray{Float64}(0.67488)      Gray{Float64}(0.461971)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float64}(0.276732)  Gray{Float64}(0.271385)     Gray{Float64}(0.596735)
#  Gray{Float64}(0.261849)  Gray{Float64}(0.249865)  …  Gray{Float64}(0.588459)
#  Gray{Float64}(0.249253)  Gray{Float64}(0.236773)     Gray{Float64}(0.587963)
#  Gray{Float64}(0.244479)  Gray{Float64}(0.23371)      Gray{Float64}(0.591209)
#  Gray{Float64}(0.285348)  Gray{Float64}(0.278146)     Gray{Float64}(0.655605)
#  Gray{Float64}(0.271463)  Gray{Float64}(0.258844)     Gray{Float64}(0.651261)
#  Gray{Float64}(0.247154)  Gray{Float64}(0.239511)  …  Gray{Float64}(0.640207)
#  Gray{Float64}(0.224744)  Gray{Float64}(0.217654)     Gray{Float64}(0.614322)
#  Gray{Float64}(0.201248)  Gray{Float64}(0.199587)     Gray{Float64}(0.58611)
#  Gray{Float64}(0.174131)  Gray{Float64}(0.173816)     Gray{Float64}(0.56445)
#  Gray{Float64}(0.149784)  Gray{Float64}(0.151803)     Gray{Float64}(0.549245)
#  Gray{Float64}(0.141622)  Gray{Float64}(0.142819)  …  Gray{Float64}(0.533334)

# %%
Width
# Out:
# UndefVarError: Width not defined

# %% [markdown]
# ## Applying Pnew on another pictures

# %%
obama = imread("obama.png")

new = stitch(obama, Pnew)

error = 10^4 * sum((img - new).^2) / (Width*Height)
println("Error measured: $error")
#save("NNgirl.png", new)
colorview(Gray, new)
# Out:
# Stitching
# Error measured: 841.7127408085947
# 256×256 Array{Gray{Float64},2}:
#  Gray{Float64}(0.189798)  Gray{Float64}(0.196584)  …  Gray{Float64}(0.67483)
#  Gray{Float64}(0.185808)  Gray{Float64}(0.188562)     Gray{Float64}(0.676042)
#  Gray{Float64}(0.176135)  Gray{Float64}(0.182961)     Gray{Float64}(0.677031)
#  Gray{Float64}(0.166862)  Gray{Float64}(0.17252)      Gray{Float64}(0.67872)
#  Gray{Float64}(0.157485)  Gray{Float64}(0.161651)     Gray{Float64}(0.681761)
#  Gray{Float64}(0.147497)  Gray{Float64}(0.148)     …  Gray{Float64}(0.685069)
#  Gray{Float64}(0.140285)  Gray{Float64}(0.138251)     Gray{Float64}(0.685696)
#  Gray{Float64}(0.138615)  Gray{Float64}(0.13735)      Gray{Float64}(0.686964)
#  Gray{Float64}(0.189798)  Gray{Float64}(0.196584)     Gray{Float64}(0.678983)
#  Gray{Float64}(0.185808)  Gray{Float64}(0.188562)     Gray{Float64}(0.680465)
#  Gray{Float64}(0.176135)  Gray{Float64}(0.182961)  …  Gray{Float64}(0.681974)
#  Gray{Float64}(0.166862)  Gray{Float64}(0.17252)      Gray{Float64}(0.684326)
#  Gray{Float64}(0.157485)  Gray{Float64}(0.161651)     Gray{Float64}(0.687874)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float64}(0.201933)  Gray{Float64}(0.207717)     Gray{Float64}(0.214539)
#  Gray{Float64}(0.193535)  Gray{Float64}(0.19649)   …  Gray{Float64}(0.20735)
#  Gray{Float64}(0.186948)  Gray{Float64}(0.187351)     Gray{Float64}(0.207023)
#  Gray{Float64}(0.185115)  Gray{Float64}(0.186116)     Gray{Float64}(0.205238)
#  Gray{Float64}(0.233291)  Gray{Float64}(0.241098)     Gray{Float64}(0.233214)
#  Gray{Float64}(0.230515)  Gray{Float64}(0.235014)     Gray{Float64}(0.229637)
#  Gray{Float64}(0.22423)   Gray{Float64}(0.232141)  …  Gray{Float64}(0.226607)
#  Gray{Float64}(0.218803)  Gray{Float64}(0.224879)     Gray{Float64}(0.222258)
#  Gray{Float64}(0.21292)   Gray{Float64}(0.217791)     Gray{Float64}(0.21529)
#  Gray{Float64}(0.205869)  Gray{Float64}(0.207903)     Gray{Float64}(0.208141)
#  Gray{Float64}(0.202037)  Gray{Float64}(0.201821)     Gray{Float64}(0.208056)
#  Gray{Float64}(0.20276)   Gray{Float64}(0.203078)  …  Gray{Float64}(0.206716)
